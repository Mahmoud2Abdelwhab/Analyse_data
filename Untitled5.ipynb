# %%
# import User libraries:
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Read Our Data:

# %%
data=pd.read_csv(r"D:\Employee.csv")
data
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1.0                0.38             0.53             2.0
# 1          2.0                0.80             0.86             5.0
# 2          3.0                0.11             0.88             7.0
# 3          4.0                0.72             0.87             5.0
# 4          5.0                0.37             0.52             2.0
# ...        ...                 ...              ...             ...
# 15782  14995.0                0.40             0.57             2.0
# 15783  14996.0                0.37             0.48             2.0
# 15784  14997.0                0.37             0.53             2.0
# 15785  14998.0                0.11             0.96             6.0
# 15786  14999.0                0.37             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                     157.0                 3.0            0.0
# ...

# %%
#Show First 10 Rows in The Data:
data.head(10)
# Out:
#    Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0     1.0                0.38             0.53             2.0
# 1     2.0                0.80             0.86             5.0
# 2     3.0                0.11             0.88             7.0
# 3     4.0                0.72             0.87             5.0
# 4     5.0                0.37             0.52             2.0
# 5     6.0                0.41             0.50             2.0
# 6     7.0                0.10             0.77             6.0
# 7     8.0                0.92             0.85             5.0
# 8     9.0                0.89             1.00             5.0
# 9    10.0                0.42             0.53             2.0
#
#    average_montly_hours  time_spend_company  Work_accident  \
# 0                 157.0                 3.0            0.0
# 1                 262.0                 6.0            0.0
# 2                 272.0                 4.0            0.0
# ...

# %%
#Data Information:
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15787 entries, 0 to 15786
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Emp ID                 14999 non-null  float64
#  1   satisfaction_level     14999 non-null  float64
#  2   last_evaluation        14999 non-null  float64
#  3   number_project         14999 non-null  float64
#  4   average_montly_hours   14999 non-null  float64
#  5   time_spend_company     14999 non-null  float64
#  6   Work_accident          14999 non-null  float64
#  7   promotion_last_5years  14999 non-null  float64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(8), object(2)
# memory usage: 1.2+ MB

# %%
Data Cleaning:

# %%
data.isna().sum()
# Out:
# Emp ID                   788
# satisfaction_level       788
# last_evaluation          788
# number_project           788
# average_montly_hours     788
# time_spend_company       788
# Work_accident            788
# promotion_last_5years    788
# dept                     788
# salary                   788
# dtype: int64

# %%
sns.heatmap(data.isna())
# Out:
# <Axes: >

# %%
d=data.iloc[12785:13571]
d
# Out:
#        Emp ID  satisfaction_level  last_evaluation  number_project  \
# 12785     NaN                 NaN              NaN             NaN
# 12786     NaN                 NaN              NaN             NaN
# 12787     NaN                 NaN              NaN             NaN
# 12788     NaN                 NaN              NaN             NaN
# 12789     NaN                 NaN              NaN             NaN
# ...       ...                 ...              ...             ...
# 13566     NaN                 NaN              NaN             NaN
# 13567     NaN                 NaN              NaN             NaN
# 13568     NaN                 NaN              NaN             NaN
# 13569     NaN                 NaN              NaN             NaN
# 13570     NaN                 NaN              NaN             NaN
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 12785                   NaN                 NaN            NaN
# ...

# %%
d.describe()
# Out:
#        Emp ID  satisfaction_level  last_evaluation  number_project  \
# count     0.0                 0.0              0.0             0.0
# mean      NaN                 NaN              NaN             NaN
# std       NaN                 NaN              NaN             NaN
# min       NaN                 NaN              NaN             NaN
# 25%       NaN                 NaN              NaN             NaN
# 50%       NaN                 NaN              NaN             NaN
# 75%       NaN                 NaN              NaN             NaN
# max       NaN                 NaN              NaN             NaN
#
#        average_montly_hours  time_spend_company  Work_accident  \
# count                   0.0                 0.0            0.0
# mean                    NaN                 NaN            NaN
# std                     NaN                 NaN            NaN
# min                     NaN                 NaN            NaN
# ...

# %%
data=data.dropna()
data
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1.0                0.38             0.53             2.0
# 1          2.0                0.80             0.86             5.0
# 2          3.0                0.11             0.88             7.0
# 3          4.0                0.72             0.87             5.0
# 4          5.0                0.37             0.52             2.0
# ...        ...                 ...              ...             ...
# 15782  14995.0                0.40             0.57             2.0
# 15783  14996.0                0.37             0.48             2.0
# 15784  14997.0                0.37             0.53             2.0
# 15785  14998.0                0.11             0.96             6.0
# 15786  14999.0                0.37             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                     157.0                 3.0            0.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14999 entries, 0 to 15786
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Emp ID                 14999 non-null  float64
#  1   satisfaction_level     14999 non-null  float64
#  2   last_evaluation        14999 non-null  float64
#  3   number_project         14999 non-null  float64
#  4   average_montly_hours   14999 non-null  float64
#  5   time_spend_company     14999 non-null  float64
#  6   Work_accident          14999 non-null  float64
#  7   promotion_last_5years  14999 non-null  float64
#  8   dept                   14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(8), object(2)
# memory usage: 1.3+ MB

# %%
sns.heatmap(data.isna())
# Out:
# <Axes: >

# %%
 Analyse data:

# %%
data["Emp ID"].count()
# Out:
# 14999

# %%
data['satisfaction_level'].max()
# Out:
# 1.0

# %%
data[data['satisfaction_level']==1]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 2023    2024.0                 1.0             0.41             4.0
# 2101    2102.0                 1.0             0.74             3.0
# 2111    2112.0                 1.0             0.92             5.0
# 2163    2164.0                 1.0             0.49             3.0
# 2193    2194.0                 1.0             0.66             4.0
# ...        ...                 ...              ...             ...
# 14071  13284.0                 1.0             0.86             2.0
# 14121  13334.0                 1.0             0.77             5.0
# 14205  13418.0                 1.0             0.72             5.0
# 14328  13541.0                 1.0             0.74             2.0
# 14374  13587.0                 1.0             0.93             5.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 2023                  174.0                 3.0            0.0
# ...

# %%
(data[data['satisfaction_level']==1]).count()
# Out:
# Emp ID                   111
# satisfaction_level       111
# last_evaluation          111
# number_project           111
# average_montly_hours     111
# time_spend_company       111
# Work_accident            111
# promotion_last_5years    111
# dept                     111
# salary                   111
# dtype: int64

# %%
data[data['satisfaction_level']==1].sort_values(by="Emp ID",ascending=True)[:10]
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 2023  2024.0                 1.0             0.41             4.0
# 2101  2102.0                 1.0             0.74             3.0
# 2111  2112.0                 1.0             0.92             5.0
# 2163  2164.0                 1.0             0.49             3.0
# 2193  2194.0                 1.0             0.66             4.0
# 2295  2296.0                 1.0             0.86             4.0
# 2321  2322.0                 1.0             0.65             4.0
# 2491  2492.0                 1.0             0.94             4.0
# 3016  3017.0                 1.0             0.81             5.0
# 3155  3156.0                 1.0             0.89             3.0
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 2023                 174.0                 3.0            0.0
# 2101                 220.0                 4.0            0.0
# ...

# %%
data['satisfaction_level'].min()
# Out:
# 0.09

# %%
data[data['satisfaction_level']==0.09]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 22        23.0                0.09             0.95             6.0
# 30        31.0                0.09             0.62             6.0
# 44        45.0                0.09             0.89             6.0
# 71        72.0                0.09             0.77             5.0
# 73        74.0                0.09             0.87             7.0
# ...        ...                 ...              ...             ...
# 15697  14910.0                0.09             0.93             6.0
# 15706  14919.0                0.09             0.89             6.0
# 15751  14964.0                0.09             0.95             6.0
# 15767  14980.0                0.09             0.93             6.0
# 15779  14992.0                0.09             0.81             6.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 22                    304.0                 4.0            0.0
# ...

# %%
data[data['satisfaction_level']==0.09].sort_values(by="Emp ID",ascending=True)
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 22        23.0                0.09             0.95             6.0
# 30        31.0                0.09             0.62             6.0
# 44        45.0                0.09             0.89             6.0
# 71        72.0                0.09             0.77             5.0
# 73        74.0                0.09             0.87             7.0
# ...        ...                 ...              ...             ...
# 15697  14910.0                0.09             0.93             6.0
# 15706  14919.0                0.09             0.89             6.0
# 15751  14964.0                0.09             0.95             6.0
# 15767  14980.0                0.09             0.93             6.0
# 15779  14992.0                0.09             0.81             6.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 22                    304.0                 4.0            0.0
# ...

# %%
data['satisfaction_level'].mean().round(2)
# Out:
# 0.61

# %%
data[data['satisfaction_level']==0.61][:10]
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 322    323.0                0.61             0.47             2.0
# 948    949.0                0.61             0.86             4.0
# 1541  1542.0                0.61             0.46             5.0
# 1836  1837.0                0.61             0.58             2.0
# 2028  2029.0                0.61             0.98             3.0
# 2037  2038.0                0.61             0.41             3.0
# 2099  2100.0                0.61             0.95             5.0
# 2116  2117.0                0.61             0.85             5.0
# 2227  2228.0                0.61             0.95             4.0
# 2231  2232.0                0.61             0.84             5.0
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 322                  253.0                 3.0            0.0
# 948                  196.0                 4.0            0.0
# ...

# %%
data['last_evaluation'].max()
# Out:
# 1.0

# %%
data[data['last_evaluation']==1.0]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 8          9.0                0.89              1.0             5.0
# 59        60.0                0.85              1.0             4.0
# 91        92.0                0.89              1.0             5.0
# 99       100.0                0.90              1.0             5.0
# 106      107.0                0.91              1.0             4.0
# ...        ...                 ...              ...             ...
# 15570  14783.0                0.73              1.0             4.0
# 15654  14867.0                0.77              1.0             4.0
# 15665  14878.0                0.84              1.0             5.0
# 15684  14897.0                0.75              1.0             5.0
# 15747  14960.0                0.59              1.0             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 8                     224.0                 5.0            0.0
# ...

# %%
data[data['last_evaluation']==1.0].sort_values(by="satisfaction_level",ascending=False)[:10]
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 4143  4144.0                1.00              1.0             5.0
# 2817  2818.0                0.99              1.0             4.0
# 5317  5318.0                0.99              1.0             3.0
# 5783  5784.0                0.98              1.0             5.0
# 6314  6315.0                0.98              1.0             4.0
# 5498  5499.0                0.97              1.0             5.0
# 6809  6810.0                0.97              1.0             3.0
# 6896  6897.0                0.96              1.0             3.0
# 8096  8097.0                0.96              1.0             3.0
# 2241  2242.0                0.96              1.0             5.0
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 4143                 142.0                 4.0            0.0
# 2817                 223.0                 2.0            1.0
# ...

# %%
sns.pairplot(data)

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_9292\2578434383.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(),annot=True)
# <Axes: >

# %%
data['number_project'].max()
# Out:
# 7.0

# %%
data[data['number_project']==7.0]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 2          3.0                0.11             0.88             7.0
# 43        44.0                0.10             0.80             7.0
# 54        55.0                0.10             0.92             7.0
# 56        57.0                0.11             0.94             7.0
# 61        62.0                0.11             0.93             7.0
# ...        ...                 ...              ...             ...
# 15687  14900.0                0.10             0.81             7.0
# 15696  14909.0                0.10             0.87             7.0
# 15717  14930.0                0.10             0.83             7.0
# 15721  14934.0                0.10             0.94             7.0
# 15763  14976.0                0.10             0.79             7.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 2                     272.0                 4.0            0.0
# ...

# %%
data[data['number_project']==7.0].sort_values(by='satisfaction_level',ascending=False)[:10]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 843      844.0                0.66             0.47             7.0
# 497      498.0                0.59             0.49             7.0
# 12497  12498.0                0.59             0.49             7.0
# 15496  14709.0                0.59             0.49             7.0
# 1988    1989.0                0.51             0.60             7.0
# 12135  12136.0                0.31             0.84             7.0
# 135      136.0                0.31             0.84             7.0
# 15134  14347.0                0.31             0.84             7.0
# 12196  12197.0                0.27             0.54             7.0
# 15195  14408.0                0.27             0.54             7.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 843                   156.0                 2.0            0.0
# 497                   263.0                 4.0            0.0
# ...

# %%
data[data['number_project']==7.0].sort_values(by='last_evaluation',ascending=False)[:10]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 809      810.0                0.11             0.97             7.0
# 454      455.0                0.09             0.97             7.0
# 12239  12240.0                0.10             0.97             7.0
# 1037    1038.0                0.09             0.97             7.0
# 1101    1102.0                0.09             0.97             7.0
# 15238  14451.0                0.10             0.97             7.0
# 1840    1841.0                0.10             0.97             7.0
# 811      812.0                0.09             0.97             7.0
# 15664  14877.0                0.10             0.97             7.0
# 1648    1649.0                0.10             0.97             7.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 809                   310.0                 4.0            0.0
# 454                   254.0                 4.0            1.0
# ...

# %%
data['average_montly_hours'].max()
# Out:
# 310.0

# %%
data[data['average_montly_hours']==310.0]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 566      567.0                0.11             0.79             7.0
# 803      804.0                0.10             0.77             6.0
# 809      810.0                0.11             0.97             7.0
# 1059    1060.0                0.70             0.93             2.0
# 1228    1229.0                0.10             0.85             7.0
# 1482    1483.0                0.09             0.77             6.0
# 1545    1546.0                0.10             0.78             6.0
# 1578    1579.0                0.10             0.96             6.0
# 1596    1597.0                0.36             0.48             5.0
# 1717    1718.0                0.11             0.96             6.0
# 1936    1937.0                0.11             0.97             6.0
# 1939    1940.0                0.10             0.79             7.0
# 1963    1964.0                0.09             0.89             7.0
# ...

# %%
data[data['average_montly_hours']==310.0].sort_values(by='number_project',ascending=False)
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 566      567.0                0.11             0.79             7.0
# 1939    1940.0                0.10             0.79             7.0
# 15565  14778.0                0.11             0.79             7.0
# 12566  12567.0                0.11             0.79             7.0
# 1985    1986.0                0.11             0.84             7.0
# 1963    1964.0                0.09             0.89             7.0
# 15763  14976.0                0.10             0.79             7.0
# 1228    1229.0                0.10             0.85             7.0
# 809      810.0                0.11             0.97             7.0
# 1578    1579.0                0.10             0.96             6.0
# 803      804.0                0.10             0.77             6.0
# 1936    1937.0                0.11             0.97             6.0
# 1545    1546.0                0.10             0.78             6.0
# ...

# %%
data[data['average_montly_hours']==310.0].sort_values(by='number_project',ascending=True)
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 1059    1060.0                0.70             0.93             2.0
# 1596    1597.0                0.36             0.48             5.0
# 803      804.0                0.10             0.77             6.0
# 1482    1483.0                0.09             0.77             6.0
# 1545    1546.0                0.10             0.78             6.0
# 1578    1579.0                0.10             0.96             6.0
# 15760  14973.0                0.11             0.97             6.0
# 1717    1718.0                0.11             0.96             6.0
# 1936    1937.0                0.11             0.97             6.0
# 15565  14778.0                0.11             0.79             7.0
# 12566  12567.0                0.11             0.79             7.0
# 1985    1986.0                0.11             0.84             7.0
# 566      567.0                0.11             0.79             7.0
# ...

# %%
data['average_montly_hours'].min()
# Out:
# 96.0

# %%
data[data['average_montly_hours']==96.0]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 2678    2679.0                0.79             0.61             5.0
# 6778    6779.0                0.34             0.67             5.0
# 7492    7493.0                0.15             0.98             2.0
# 8605    8606.0                0.48             0.43             3.0
# 9221    9222.0                0.92             0.82             4.0
# 10020  10021.0                0.50             0.58             4.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 2678                   96.0                 4.0            0.0
# 6778                   96.0                 2.0            1.0
# 7492                   96.0                 2.0            0.0
# 8605                   96.0                 3.0            0.0
# 9221                   96.0                 4.0            0.0
# 10020                  96.0                 3.0            0.0
#
# ...

# %%
data[data['average_montly_hours']==96.0].sort_values(by='number_project',ascending=False)
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 2678    2679.0                0.79             0.61             5.0
# 6778    6779.0                0.34             0.67             5.0
# 9221    9222.0                0.92             0.82             4.0
# 10020  10021.0                0.50             0.58             4.0
# 8605    8606.0                0.48             0.43             3.0
# 7492    7493.0                0.15             0.98             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 2678                   96.0                 4.0            0.0
# 6778                   96.0                 2.0            1.0
# 9221                   96.0                 4.0            0.0
# 10020                  96.0                 3.0            0.0
# 8605                   96.0                 3.0            0.0
# 7492                   96.0                 2.0            0.0
#
# ...

# %%
data['time_spend_company'].max()
# Out:
# 10.0

# %%
data[data['time_spend_company']==10.0]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 11078  11079.0                0.69             0.88             3.0
# 11124  11125.0                0.29             0.75             6.0
# 11193  11194.0                0.75             0.60             4.0
# 11194  11195.0                0.61             0.89             3.0
# 11195  11196.0                0.47             0.79             3.0
# ...        ...                 ...              ...             ...
# 14993  14206.0                0.22             0.94             3.0
# 14994  14207.0                0.90             0.55             3.0
# 14995  14208.0                0.74             0.95             5.0
# 14996  14209.0                0.85             0.54             3.0
# 14997  14210.0                0.33             0.65             3.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 11078                 164.0                10.0            0.0
# ...

# %%
data[data['time_spend_company']==10.0].sort_values(by='number_project',ascending=False)
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 11292  11293.0                0.29             0.37             6.0
# 11636  11637.0                0.41             0.67             6.0
# 14674  13887.0                0.17             0.61             6.0
# 14564  13777.0                0.96             0.97             6.0
# 11526  11527.0                0.47             0.76             6.0
# ...        ...                 ...              ...             ...
# 14529  13742.0                0.60             0.65             2.0
# 14580  13793.0                0.57             0.93             2.0
# 11196  11197.0                0.22             0.70             2.0
# 11530  11531.0                0.60             0.65             2.0
# 14610  13823.0                0.65             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 11292                 187.0                10.0            1.0
# ...

# %%
data[data['time_spend_company']==10.0].sort_values(by='number_project',ascending=True)
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 11581  11582.0                0.57             0.93             2.0
# 11611  11612.0                0.65             0.52             2.0
# 11530  11531.0                0.60             0.65             2.0
# 11531  11532.0                0.67             0.72             2.0
# 11196  11197.0                0.22             0.70             2.0
# ...        ...                 ...              ...             ...
# 11565  11566.0                0.96             0.97             6.0
# 11124  11125.0                0.29             0.75             6.0
# 14525  13738.0                0.47             0.76             6.0
# 14291  13504.0                0.29             0.37             6.0
# 14123  13336.0                0.29             0.75             6.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 11581                 204.0                10.0            0.0
# ...

# %%
data['time_spend_company'].min()
# Out:
# 2.0

# %%
data[data['time_spend_company']==2.0]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 50        51.0                0.13             0.78             6.0
# 116      117.0                0.86             0.68             5.0
# 175      176.0                0.54             0.74             4.0
# 376      377.0                0.56             0.71             4.0
# 378      379.0                0.31             0.56             4.0
# ...        ...                 ...              ...             ...
# 15484  14697.0                0.32             0.95             5.0
# 15575  14788.0                0.48             0.78             2.0
# 15619  14832.0                0.80             0.75             3.0
# 15630  14843.0                0.34             0.67             4.0
# 15749  14962.0                0.73             0.97             6.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 50                    152.0                 2.0            0.0
# ...

# %%
data[data['time_spend_company']==2.0].sort_values(by='number_project',ascending=False)
# Out:
#       Emp ID  satisfaction_level  last_evaluation  number_project  \
# 843    844.0                0.66             0.47             7.0
# 50      51.0                0.13             0.78             6.0
# 4667  4668.0                0.62             0.87             6.0
# 6879  6880.0                0.40             1.00             6.0
# 6708  6709.0                0.79             0.97             6.0
# ...      ...                 ...              ...             ...
# 4148  4149.0                0.90             0.96             2.0
# 9939  9940.0                0.89             0.76             2.0
# 7492  7493.0                0.15             0.98             2.0
# 7481  7482.0                0.44             0.58             2.0
# 9004  9005.0                0.53             0.46             2.0
#
#       average_montly_hours  time_spend_company  Work_accident  \
# 843                  156.0                 2.0            0.0
# ...

# %%
data[data['Work_accident']==0]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1.0                0.38             0.53             2.0
# 1          2.0                0.80             0.86             5.0
# 2          3.0                0.11             0.88             7.0
# 3          4.0                0.72             0.87             5.0
# 4          5.0                0.37             0.52             2.0
# ...        ...                 ...              ...             ...
# 15782  14995.0                0.40             0.57             2.0
# 15783  14996.0                0.37             0.48             2.0
# 15784  14997.0                0.37             0.53             2.0
# 15785  14998.0                0.11             0.96             6.0
# 15786  14999.0                0.37             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                     157.0                 3.0            0.0
# ...

# %%
data[data['Work_accident']==1]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 18        19.0                0.45             0.51             2.0
# 68        69.0                0.76             0.86             5.0
# 120      121.0                0.14             0.62             4.0
# 123      124.0                0.11             0.84             6.0
# 136      137.0                0.10             0.84             6.0
# ...        ...                 ...              ...             ...
# 15728  14941.0                0.10             0.78             5.0
# 15733  14946.0                0.14             0.75             4.0
# 15737  14950.0                0.42             0.57             2.0
# 15777  14990.0                0.43             0.57             2.0
# 15778  14991.0                0.89             0.88             5.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 18                    160.0                 3.0            1.0
# ...

# %%
data[data['promotion_last_5years']==1]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 18        19.0                0.45             0.51             2.0
# 82        83.0                0.79             0.59             4.0
# 171      172.0                0.41             0.46             2.0
# 287      288.0                0.11             0.79             6.0
# 584      585.0                0.41             0.56             2.0
# ...        ...                 ...              ...             ...
# 15017  14230.0                0.45             0.51             2.0
# 15081  14294.0                0.79             0.59             4.0
# 15170  14383.0                0.41             0.46             2.0
# 15286  14499.0                0.11             0.79             6.0
# 15583  14796.0                0.41             0.56             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 18                    160.0                 3.0            1.0
# ...

# %%
data[data['promotion_last_5years']==0]
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1.0                0.38             0.53             2.0
# 1          2.0                0.80             0.86             5.0
# 2          3.0                0.11             0.88             7.0
# 3          4.0                0.72             0.87             5.0
# 4          5.0                0.37             0.52             2.0
# ...        ...                 ...              ...             ...
# 15782  14995.0                0.40             0.57             2.0
# 15783  14996.0                0.37             0.48             2.0
# 15784  14997.0                0.37             0.53             2.0
# 15785  14998.0                0.11             0.96             6.0
# 15786  14999.0                0.37             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                     157.0                 3.0            0.0
# ...

# %%
TOP=data[data['promotion_last_5years']==0].sort_values(by='number_project',ascending=False)
TOP
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 15330  14543.0                0.11             0.85             7.0
# 12778  12779.0                0.10             0.92             7.0
# 340      341.0                0.09             0.89             7.0
# 15102  14315.0                0.09             0.94             7.0
# 1600    1601.0                0.11             0.93             7.0
# ...        ...                 ...              ...             ...
# 7895    7896.0                0.70             0.47             2.0
# 7903    7904.0                0.60             0.85             2.0
# 7904    7905.0                0.90             0.76             2.0
# 7905    7906.0                0.54             0.62             2.0
# 15786  14999.0                0.37             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 15330                 302.0                 4.0            0.0
# ...

# %%
top=TOP.sort_values(by='satisfaction_level',ascending=False)
top
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 7597    7598.0                1.00             0.67             3.0
# 5702    5703.0                1.00             0.94             3.0
# 9333    9334.0                1.00             0.85             4.0
# 6602    6603.0                1.00             0.63             5.0
# 4724    4725.0                1.00             0.73             3.0
# ...        ...                 ...              ...             ...
# 12445  12446.0                0.09             0.94             6.0
# 15419  14632.0                0.09             0.96             6.0
# 12186  12187.0                0.09             0.85             6.0
# 12687  12688.0                0.09             0.92             7.0
# 1745    1746.0                0.09             0.78             6.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 7597                  181.0                 2.0            0.0
# ...

# %%
top.sort_values(by='last_evaluation',ascending=False)
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 11834  11835.0                0.53             1.00             3.0
# 873      874.0                0.78             1.00             5.0
# 545      546.0                0.78             1.00             5.0
# 2595    2596.0                0.90             1.00             4.0
# 342      343.0                0.90             1.00             5.0
# ...        ...                 ...              ...             ...
# 10430  10431.0                0.71             0.36             2.0
# 11168  11169.0                0.17             0.36             6.0
# 4058    4059.0                0.84             0.36             6.0
# 14118  13331.0                0.19             0.36             3.0
# 7400    7401.0                0.73             0.36             4.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 11834                 164.0                 4.0            0.0
# ...

# %%
data['dept'].value_counts()
# Out:
# sales          4140
# technical      2720
# support        2229
# IT             1227
# product_mng     902
# marketing       858
# RandD           787
# accounting      767
# hr              739
# management      630
# Name: dept, dtype: int64

# %%
data['dept'].value_counts().plot(kind='pie',autopct='%1.1f%%',radius=2)
plt.show()

# %%
data['dept'].value_counts().plot(kind='bar')
plt.show()

# %%
data['dept'].value_counts().plot(kind='barh')
plt.show()

# %%
data
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 0          1.0                0.38             0.53             2.0
# 1          2.0                0.80             0.86             5.0
# 2          3.0                0.11             0.88             7.0
# 3          4.0                0.72             0.87             5.0
# 4          5.0                0.37             0.52             2.0
# ...        ...                 ...              ...             ...
# 15782  14995.0                0.40             0.57             2.0
# 15783  14996.0                0.37             0.48             2.0
# 15784  14997.0                0.37             0.53             2.0
# 15785  14998.0                0.11             0.96             6.0
# 15786  14999.0                0.37             0.52             2.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 0                     157.0                 3.0            0.0
# ...

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='dept',hue='salary',data=data)
# Out:
# <Axes: xlabel='dept', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='salary',hue='dept',data=data)
# Out:
# <Axes: xlabel='salary', ylabel='count'>

# %%
sns.countplot(x='salary',hue='number_project',data=data)
# Out:
# <Axes: xlabel='salary', ylabel='count'>

# %%
data[data['salary']=='medium']
# Out:
#         Emp ID  satisfaction_level  last_evaluation  number_project  \
# 1          2.0                0.80             0.86             5.0
# 2          3.0                0.11             0.88             7.0
# 60        61.0                0.85             0.91             5.0
# 61        62.0                0.11             0.93             7.0
# 62        63.0                0.10             0.95             6.0
# ...        ...                 ...              ...             ...
# 15767  14980.0                0.09             0.93             6.0
# 15770  14983.0                0.38             0.49             2.0
# 15771  14984.0                0.72             0.84             5.0
# 15772  14985.0                0.40             0.56             2.0
# 15773  14986.0                0.91             0.99             5.0
#
#        average_montly_hours  time_spend_company  Work_accident  \
# 1                     262.0                 6.0            0.0
# ...
